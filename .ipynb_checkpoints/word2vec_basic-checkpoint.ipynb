# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %% [markdown]
# # Step 1: Download the data.

# %%
def maybe_download(filename, expected_bytes,url):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

# %%
url = 'http://mattmahoney.net/dc/'
filename = maybe_download('text8.zip', 31344016,url)
# Out:
# Found and verified text8.zip

# %% [markdown]
# # Read the data into a list of strings.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        #https://stackoverflow.com/questions/37689802/what-is-tensorflow-compat-as-str
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

# %%
words = read_data(filename)
print('Data size', len(words))
#this is a list with duplicates
print('words has type', type(words))
wordset=set(words)
print('number of unique words',len(wordset))
# Out:
# Data size 17005207
# words has type <class 'list'>
# number of unique words 253854

# %% [markdown]
# # Step 2: Build the dictionary and replace rare words with UNK token.

# %%
def build_dataset(words, vocabulary_size):
    count = [['UNK', -1]]
    #choose vocab_size -1 most frequent words. we have -1 because we need Unk as first word
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    #this stores word-index
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    # data stores the index of each word in the incoming list
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    #stores index-word
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

# %%
vocabulary_size = 50000
data, count, dictionary, reverse_dictionary = build_dataset(words, vocabulary_size)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5237, 3083, 12, 6, 195, 2, 3137, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# # Step 3: Function to generate a training batch for the skip-gram model.

# %%
data_index = 0
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    # num_skips : How many times to reuse an input to generate a label.
    # skip_window : How many words to consider left and right.
    assert batch_size % num_skips == 0
    # we can use a word only as many times as the window it has. Sometimes less if it is a first word
    assert num_skips <= 2 * skip_window
    # batch_size : 
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    # deque: list-like container with fast appends and pops on either end
    buffer = collections.deque(maxlen=span)
    #span gives the current window we are looking at
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    # // : refers to Floor Division
    for i in range(batch_size // num_skips):
        target = skip_window  
        # target label at the center of the buffer and that is equal to skip_window because we start index from 1
        # we use a deque so position of the target word remains the same
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            #this while loop is to avoid reusing context word or using the target word as context for itself
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            # buffer[skip_window]this refers to the word in the span we are interested in building a vector for
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    #labels are the context for the words in the ds batch
    return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)

for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3083 originated -> 5237 anarchism
# 3083 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3083 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of

# %% [markdown]
# # Step 4: Build and train a skip-gram model.
#  Given a specific word in the middle of a sentence (the input word), look at the words nearby and pick one at random. The network is going to tell us the probability for every word in our vocabulary of being the “nearby word” that we chose. A good tutorial for skip gram model is here (http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/)
#
#  Here , we use labels as such with the NCE function without using its embeddings.

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

# %% [markdown]
# # build tensorflow Model now
# This is basically the model we have in network.py

# %%
graph = tf.Graph()

with graph.as_default():
    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size]) # words for which we want the embeddings
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])# these are the contexts 
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    # This is the hidden layer we are interested in 
        embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    # this is the loss function we optimize for. 
    # There is an intuitive explanation of this loss function towards the end of this notebook
    # According to documentation:By default nce_loss uses a log-uniform (Zipfian) distribution for sampling, 
    # so your labels must be sorted in order of decreasing frequency to achieve good results.
    loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    # this function is the funal function we use to obtain the word vectors
    normalized_embeddings = embeddings / norm
    
    valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
    
    similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)
    # Add variable initializer to the graph.
    init = tf.global_variables_initializer()

# %% [markdown]
# # Step 5: Begin training.

# %%
num_steps = 100001
with tf.Session( graph = graph ) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")
    average_loss = 0
    for step in xrange(num_steps):
        #genereate data in batches
        batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val
        # Every 2000 steps we monitor how the loss is coming along
        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0
        # This step is to see how well the embeddings perform on eval data set
        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "Nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  293.718017578
# Nearest to all: civilisation, lectionis, medicare, publius, jb, griffith, idi, northampton,
# Nearest to during: soy, utr, verizon, manfred, deconstruction, masoch, buddy, cbs,
# Nearest to to: shroud, tangerine, partake, zut, warmest, fairies, flavius, trist,
# Nearest to of: mandolins, reigns, cryptography, crispy, sap, canton, auchinleck, wollheim,
# Nearest to when: nuclear, irb, cogito, petomane, logical, zout, prairie, niece,
# Nearest to they: maltese, massed, waterfall, monotheist, precept, withdrawal, fascism, silverstein,
# Nearest to system: sarmatian, saarinen, putsch, smuggled, mediation, moldavia, anticipation, wallace,
# Nearest to would: neuropsychological, cans, translates, frankenchrist, stanford, insulate, knightly, vesta,
# Nearest to while: meld, glands, replicates, alg, enforced, twister, slanted, artform,
# Nearest to their: shab, diem, ablation, tomorrowland, cassian, oceans, becker, phenomenon,
# Nearest to known: stv, wheelers, greenfacts, wat, durham, detract, woodford, tice,
# Nearest to no: stanton, secombe, spartans, biking, interment, conway, repulsive, ambushes,
# Nearest to that: alif, gland, avenue, renarrative, pairwise, miyamoto, un, asses,
# Nearest to will: tropic, downturn, mata, heflin, ibiza, bobby, obedient, yorke,
# Nearest to he: devolved, auratus, specifier, facie, bribed, conciliar, avoided, consulate,
# Nearest to more: cure, gallows, dahl, cleanly, adder, breathing, temperaments, avenida,
# Average loss at step  2000 :  113.987534389
# Average loss at step  4000 :  52.8036639798
# Average loss at step  6000 :  33.6964583054
# Average loss at step  8000 :  23.47445762
# Average loss at step  10000 :  17.5893901906
# Nearest to all: township, netbios, absalom, turn, shrew, sound, whom, mtu,
# Nearest to during: dor, concern, deconstruction, dispersion, of, cbs, composer, earth,
# Nearest to to: and, for, township, in, explore, hz, dor, spring,
# Nearest to of: in, and, with, for, s, nine, dor, township,
# Nearest to when: nuclear, logical, seven, referred, ronstadt, or, death, scalability,
# Nearest to they: maltese, dar, who, township, there, antiquity, cuon, this,
# Nearest to system: wallace, chief, minicomputer, authors, failure, base, potash, township,
# Nearest to would: beautiful, oak, dor, translates, cur, congress, corgi, stanford,
# Nearest to while: nichols, servers, forming, nf, township, drives, mtu, mental,
# Nearest to their: the, tomorrowland, height, phenomenon, fires, filippo, comparison, hot,
# Nearest to known: township, dor, cc, ordered, but, masters, netbios, reference,
# Nearest to no: mtu, rna, spartans, dsp, netbios, israeli, spoke, guatemalan,
# Nearest to that: gland, restriction, township, also, writings, green, desired, un,
# Nearest to will: bobby, and, dor, diagnosis, adobe, hazards, marie, livery,
# Nearest to he: township, devolved, it, hz, follows, shoes, who, steal,
# Nearest to more: township, employed, superfamily, zero, innocent, tentatively, cure, levels,
# Average loss at step  12000 :  14.1060598805
# Average loss at step  14000 :  11.2064581454
# Average loss at step  16000 :  9.45578223181
# Average loss at step  18000 :  8.84487954354
# Average loss at step  20000 :  8.08431899738
# Nearest to all: township, netbios, lagenorhynchus, these, laud, fixed, shrew, whom,
# Nearest to during: in, concern, of, kilby, dor, dear, dispersion, cbs,
# Nearest to to: for, township, can, hz, dor, will, and, nine,
# Nearest to of: in, and, for, township, nine, dor, from, original,
# Nearest to when: or, nuclear, logical, seven, and, as, is, bigg,
# Nearest to they: there, maltese, who, dar, it, tuileries, still, this,
# Nearest to system: gentry, chief, wallace, authors, mediation, anticipation, township, failure,
# Nearest to would: can, may, oak, will, beautiful, cur, dor, could,
# Nearest to while: servers, nichols, forming, enforced, drives, nf, township, inhibition,
# Nearest to their: the, its, height, salamander, tomorrowland, tuileries, quake, buy,
# Nearest to known: zn, such, masters, township, eml, arabs, but, cc,
# Nearest to no: mtu, spartans, rna, gurps, spoke, israeli, guatemalan, dsp,
# Nearest to that: which, desired, township, also, this, restriction, intellectual, hz,
# Nearest to will: to, can, hazards, and, would, corrosion, diagnosis, marie,
# Nearest to he: it, who, devolved, township, hz, follows, shoes, lagenorhynchus,
# Nearest to more: bigg, temperaments, employed, innocent, township, consoles, superfamily, mold,
# Average loss at step  22000 :  7.4917304101
# Average loss at step  24000 :  7.03478811967
# Average loss at step  26000 :  6.63110512781
# Average loss at step  28000 :  6.3902128067
# Average loss at step  30000 :  5.87792026532
# Nearest to all: these, township, fixed, lagenorhynchus, netbios, fushimi, shrew, laud,
# Nearest to during: of, in, concern, kilby, dispersion, guatemala, octaves, on,
# Nearest to to: can, township, will, for, dor, nine, neutronic, with,
# Nearest to of: in, for, and, township, dravidian, nine, dor, trinity,
# Nearest to when: or, and, seven, logical, was, bigg, ronstadt, nuclear,
# Nearest to they: there, he, it, who, maltese, dar, we, tuileries,
# Nearest to system: gentry, wallace, authors, chief, mar, township, failure, anticipation,
# Nearest to would: will, can, may, could, must, oak, burkert, to,
# Nearest to while: and, nichols, drives, servers, forming, township, if, enforced,
# Nearest to their: the, its, his, barcode, height, quake, salamander, township,
# Nearest to known: such, brie, darnley, masters, zn, arabs, bombers, truly,
# Nearest to no: a, mtu, gurps, rna, dsp, nine, spartans, spoke,
# Nearest to that: which, also, this, it, desired, township, neutronic, restriction,
# Nearest to will: can, would, to, may, downturn, hazards, corrosion, diagnosis,
# Nearest to he: it, who, they, township, she, follows, devolved, there,
# Nearest to more: bigg, most, employed, vdp, innocent, temperaments, less, deities,
# Average loss at step  32000 :  5.79096553564
# Average loss at step  34000 :  5.64519022167
# Average loss at step  36000 :  5.65171107841
# Average loss at step  38000 :  5.47507054758
# Average loss at step  40000 :  5.32652810872
# Nearest to all: these, fixed, fushimi, lagenorhynchus, shrew, township, netbios, the,
# Nearest to during: in, of, on, kilby, octaves, guatemala, dispersion, concern,
# Nearest to to: for, can, will, township, dor, would, not, nine,
# Nearest to of: in, for, and, township, dravidian, during, nine, seven,
# Nearest to when: or, was, but, logical, seven, as, is, ronstadt,
# Nearest to they: he, there, it, we, who, maltese, you, still,
# Nearest to system: gentry, chief, township, fukuyama, mar, wallace, authors, moldavia,
# Nearest to would: can, will, may, could, must, to, burkert, should,
# Nearest to while: and, if, nichols, drives, forming, servers, enforced, ikeda,
# Nearest to their: its, his, the, quake, barcode, tomorrowland, township, height,
# Nearest to known: such, brie, darnley, vulpes, masters, arabs, zn, truly,
# Nearest to no: a, gurps, mtu, rna, spoke, enactment, spartans, dsp,
# Nearest to that: which, this, township, desired, restriction, it, but, also,
# Nearest to will: can, would, may, to, could, hazards, downturn, diagnosis,
# Nearest to he: it, who, they, she, there, township, follows, hz,
# Nearest to more: bigg, most, less, vdp, innocent, employed, temperaments, gendarmerie,
# Average loss at step  42000 :  5.72875988346
# Average loss at step  44000 :  5.27044332755
# Average loss at step  46000 :  5.23276329863
# Average loss at step  48000 :  5.17575430334
# Average loss at step  50000 :  5.04148477185
# Nearest to all: these, mvs, lagenorhynchus, yourdon, some, fixed, fac, netbios,
# Nearest to during: in, on, of, zilog, glas, from, kilby, octaves,
# Nearest to to: can, township, for, nine, will, dor, would, yourdon,
# Nearest to of: in, seven, township, nine, glas, for, and, eight,
# Nearest to when: seven, was, but, or, is, since, as, logical,
# Nearest to they: he, there, we, it, you, who, she, not,
# Nearest to system: gentry, township, wallace, chief, mar, fukuyama, moldavia, failure,
# Nearest to would: can, will, may, could, must, should, to, burkert,
# Nearest to while: if, and, though, nichols, drives, glas, ikeda, township,
# Nearest to their: its, his, the, quake, her, tomorrowland, township, goths,
# Nearest to known: such, brie, truly, arabs, vulpes, darnley, masters, zn,
# Nearest to no: gurps, a, mtu, or, rna, guatemalan, neutronic, spoke,
# Nearest to that: which, this, township, however, also, it, desired, but,
# Nearest to will: can, would, may, could, to, downturn, hazards, should,
# Nearest to he: it, who, they, she, there, vengeance, follows, tetra,
# Nearest to more: less, most, bigg, innocent, vdp, employed, temperaments, gendarmerie,
# Average loss at step  52000 :  4.95201331365
# Average loss at step  54000 :  5.05690123892
# Average loss at step  56000 :  5.13647851694
# Average loss at step  58000 :  5.05635546029
# Average loss at step  60000 :  5.00117178011
# Nearest to all: these, mvs, some, yourdon, many, lagenorhynchus, fac, netbios,
# Nearest to during: in, on, zilog, of, glas, after, kilby, octaves,
# Nearest to to: will, can, nine, township, for, into, not, could,
# Nearest to of: in, glas, township, nine, and, for, dor, seven,
# Nearest to when: but, and, was, as, since, or, seven, logical,
# Nearest to they: he, there, we, it, you, who, she, still,
# Nearest to system: gentry, township, chief, mar, wallace, fukuyama, moldavia, mediation,
# Nearest to would: can, will, may, could, must, should, gallifrey, might,
# Nearest to while: if, and, although, though, when, glas, township, dravidian,
# Nearest to their: its, his, the, her, gru, township, brie, tomorrowland,
# Nearest to known: such, truly, arabs, brie, masters, darnley, vulpes, used,
# Nearest to no: a, mtu, gurps, now, neutronic, this, any, spoke,
# Nearest to that: which, this, township, however, pendulum, but, also, it,
# Nearest to will: can, would, may, could, to, should, downturn, must,
# Nearest to he: it, she, who, they, there, tetra, township, vengeance,
# Nearest to more: less, most, bigg, very, innocent, employed, vdp, gendarmerie,
# Average loss at step  62000 :  4.98390109622
# Average loss at step  64000 :  4.89007574159
# Average loss at step  66000 :  4.78348791575
# Average loss at step  68000 :  4.8495679636
# Average loss at step  70000 :  4.86656455505
# Nearest to all: these, many, some, mvs, yourdon, lagenorhynchus, each, both,
# Nearest to during: in, of, on, zilog, after, glas, by, but,
# Nearest to to: will, can, township, for, dor, could, would, should,
# Nearest to of: glas, township, in, during, nine, dor, eight, six,
# Nearest to when: but, was, since, as, is, after, although, however,
# Nearest to they: he, there, we, you, it, who, she, not,
# Nearest to system: gentry, township, mar, moldavia, wallace, chief, lands, dissolution,
# Nearest to would: will, can, may, could, must, should, might, gallifrey,
# Nearest to while: although, if, though, and, when, however, but, in,
# Nearest to their: its, his, the, her, township, gru, brie, goths,
# Nearest to known: such, truly, used, brie, arabs, masters, darnley, stadtbahn,
# Nearest to no: a, any, mtu, gurps, or, neutronic, usually, partisan,
# Nearest to that: which, this, however, township, but, it, desired, eph,
# Nearest to will: can, would, may, could, to, should, must, might,
# Nearest to he: it, she, they, who, there, vengeance, never, township,
# Nearest to more: less, most, bigg, very, innocent, employed, vdp, not,
# Average loss at step  72000 :  4.81764404714
# Average loss at step  74000 :  4.84200647461
# Average loss at step  76000 :  4.83621701634
# Average loss at step  78000 :  4.74516526163
# Average loss at step  80000 :  4.80227516174
# Nearest to all: these, some, many, both, mvs, yourdon, lagenorhynchus, glas,
# Nearest to during: in, after, on, from, but, throughout, zilog, of,
# Nearest to to: can, will, would, township, gard, yourdon, nine, could,
# Nearest to of: landesverband, glas, township, for, nine, in, dor, during,
# Nearest to when: but, after, although, if, while, since, was, however,
# Nearest to they: he, there, we, you, it, who, she, not,
# Nearest to system: gentry, township, dissolution, chief, mar, wallace, fukuyama, moldavia,
# Nearest to would: will, can, may, could, must, should, might, to,
# Nearest to while: landesverband, although, and, though, when, if, but, however,
# Nearest to their: its, his, the, her, landesverband, these, them, gru,
# Nearest to known: such, used, truly, brie, arabs, masters, corresponds, well,
# Nearest to no: a, any, gurps, only, mtu, partisan, landesverband, usually,
# Nearest to that: which, this, however, township, desired, but, landesverband, eph,
# Nearest to will: can, would, may, could, should, must, to, might,
# Nearest to he: it, she, they, who, there, vengeance, never, hyi,
# Nearest to more: less, most, very, bigg, innocent, employed, vdp, township,
# Average loss at step  82000 :  4.71987692666
# Average loss at step  84000 :  4.77908919144
# Average loss at step  86000 :  4.52695152056
# Average loss at step  88000 :  4.65311779737
# Average loss at step  90000 :  4.76852203941
# Nearest to all: these, some, many, both, mvs, yourdon, lagenorhynchus, risotto,
# Nearest to during: in, after, from, of, on, throughout, at, although,
# Nearest to to: can, will, would, township, nine, gard, yourdon, neutronic,
# Nearest to of: in, landesverband, glas, for, township, dor, during, nine,
# Nearest to when: after, but, although, if, while, before, since, however,
# Nearest to they: there, we, he, you, it, who, she, not,
# Nearest to system: gentry, township, systems, honorific, fukuyama, dissolution, mar, lands,
# Nearest to would: will, can, may, could, must, should, might, to,
# Nearest to while: although, though, and, landesverband, when, however, if, but,
# Nearest to their: its, his, her, the, landesverband, risotto, these, them,
# Nearest to known: such, used, truly, brie, masters, well, corresponds, arabs,
# Nearest to no: a, any, gurps, mtu, loathing, partisan, landesverband, hyi,
# Nearest to that: which, this, however, township, desired, but, also, landesverband,
# Nearest to will: would, can, may, could, should, must, might, to,
# Nearest to he: it, she, they, who, there, never, vengeance, soon,
# Nearest to more: less, most, very, bigg, not, innocent, township, employed,
# Average loss at step  92000 :  4.66047452438
# Average loss at step  94000 :  4.63749790883
# Average loss at step  96000 :  4.60144100595
# Average loss at step  98000 :  4.62469342148
# Average loss at step  100000 :  4.3649369539
# Nearest to all: these, some, many, both, mvs, lagenorhynchus, yourdon, those,
# Nearest to during: in, after, from, of, at, on, although, however,
# Nearest to to: will, would, township, can, dor, could, neutronic, for,
# Nearest to of: in, during, landesverband, dor, glas, cccc, despite, and,
# Nearest to when: if, although, after, but, while, since, however, before,
# Nearest to they: he, there, we, you, it, she, who, not,
# Nearest to system: systems, gentry, dissolution, township, fukuyama, hybrids, moldavia, lands,
# Nearest to would: will, can, may, could, must, should, might, to,
# Nearest to while: although, though, when, however, landesverband, if, but, or,
# Nearest to their: its, his, her, the, these, landesverband, some, your,
# Nearest to known: such, used, truly, described, brie, well, masters, cosmology,
# Nearest to no: any, loathing, gurps, a, mtu, only, partisan, nine,
# Nearest to that: which, however, this, desired, but, township, landesverband, pendulum,
# Nearest to will: would, can, could, may, should, must, might, to,
# Nearest to he: it, she, they, there, who, never, soon, vengeance,
# Nearest to more: less, most, very, bigg, not, innocent, township, employed,

# %% [markdown]
# # Step 6: Visualize the embeddings.

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

    plt.savefig(filename)

# %%
try:
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt
    # %matplotlib inline
    #T-SNE needs dimensionality reductions for good visualizations
    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels)
except ImportError:
    print("Please install sklearn, matplotlib, and scipy to visualize embeddings.")

# %% [markdown]
# # Intuition behind our loss function called the Noise Contrastive estimation
# https://datascience.stackexchange.com/questions/13216/intuitive-explanation-of-noise-contrastive-estimation-nce-loss
#
# The issue:
#
# There are some issues with learning the word vectors using an "standard" neural network. In this way, the word vectors are learned while the network learns to predict the next word given a window of words (the input of the network).
#
# Predicting the next word is like predicting the class. That is, such a network is just a "standard" multinomial (multi-class) classifier. And this network must have as many output neurons as classes there are. When classes are actual words, the number of neurons is, well, huge.
#
# A "standard" neural network is usually trained with a cross-entropy cost function which requires the values of the output neurons to represent probabilities - which means that the output "scores" computed by the network for each class have to be normalized, converted into actual probabilities for each class. This normalization step is achieved by means of the softmax function. Softmax is very costly when applied to a huge output layer.
#
# The (a) solution:
#
# In order to deal with this issue, that is, the expensive computation of the softmax, Word2Vec uses a technique called noise-contrastive estimation. This technique was introduced by [A] (reformulated by [B]) then used in [C], [D], [E] to learn word embeddings from unlabelled natural language text.
#
# The basic idea is to convert a multinomial classification problem (as it is the problem of predicting the next word) to a binary classification problem. That is, instead of using softmax to estimate a true probability distribution of the output word, a binary logistic regression (binary classification) is used instead.
#
# For each training sample, the enhanced (optimized) classifier is fed a true pair (a center word and another word that appears in its context) and a number of kk randomly corrupted pairs (consisting of the center word and a randomly chosen word from the vocabulary). By learning to distinguish the true pairs from corrupted ones, the classifier will ultimately learn the word vectors.
#
# This is important: instead of predicting the next word (the "standard" training technique), the optimized classifier simply predicts whether a pair of words is good or bad.
#
# Word2Vec slightly customizes the process and calls it negative sampling. In Word2Vec, the words for the negative samples (used for the corrupted pairs) are drawn from a specially designed distribution, which favours less frequent words to be drawn more often.
#
# References
#
# [A] (2005) - Contrastive estimation: Training log-linear models on unlabeled data
#
# [B] (2010) - Noise-contrastive estimation: A new estimation principle for unnormalized statistical models
#
# [C] (2008) - A unified architecture for natural language processing: Deep neural networks with multitask learning
#
# [D] (2012) - A fast and simple algorithm for training neural probabilistic language models.
#
# [E] (2013) - Learning word embeddings efficiently with noise-contrastive estimation.
#
# Another good explanation is here
# https://stackoverflow.com/questions/41475180/understanding-tf-nn-nce-loss-in-tensorflow
